# %%
import numpy
import camelot as cm

# %%
input_pdf = cm.read_pdf("LIST-OF-SUCCESSFUL-CANDIDATES-FOR-UPLOADING-1.pdf", pages='all', line_scale=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 input_pdf = cm.read_pdf("LIST-OF-SUCCESSFUL-CANDIDATES-FOR-UPLOADING-1.pdf", flavor="stream", pages='1,2,3,4,5,6,7,8,9', line_scale=20)
#
# File ~/anaconda3/lib/python3.9/site-packages/camelot/io.py:110, in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     107 if suppress_stdout:
#     108     warnings.simplefilter("ignore")
# --> 110 validate_input(kwargs, flavor=flavor)
#     111 p = PDFHandler(filepath, pages=pages, password=password)
#     112 kwargs = remove_extra(kwargs, flavor=flavor)
#
# File ~/anaconda3/lib/python3.9/site-packages/camelot/utils.py:122, in validate_input(kwargs, flavor)
#     120     check_intersection(stream_kwargs, kwargs)
#     121 else:
# --> 122     check_intersection(lattice_kwargs, kwargs)
#
# ...

# %%
help(cm)
# Out:
# Help on package camelot:
#
# NAME
#     camelot - # -*- coding: utf-8 -*-
#
# PACKAGE CONTENTS
#     __main__
#     __version__
#     backends (package)
#     cli
#     core
#     handlers
#     image_processing
#     io
#     parsers (package)
#     plotting
#     utils
#
# DATA
#     format_string = '%(asctime)s - %(levelname)s - %(message)s'
#     formatter = <logging.Formatter object>
#     handler = <StreamHandler stderr (NOTSET)>
#     logger = <Logger camelot (WARNING)>
#     plot = <camelot.plotting.PlotMethods object>
#
# VERSION
#     0.10.1
#
# FILE
#     /home/codingsolutions/anaconda3/lib/python3.9/site-packages/camelot/__init__.py

# %%
input_pdf
help(input_pdf)
# Out:
# Help on TableList in module camelot.core object:
#
# class TableList(builtins.object)
#  |  TableList(tables)
#  |
#  |  Defines a list of camelot.core.Table objects. Each table can
#  |  be accessed using its index.
#  |
#  |  Attributes
#  |  ----------
#  |  n : int
#  |      Number of tables in the list.
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, idx)
#  |
#  |  __init__(self, tables)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __len__(self)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  export(self, path, f='csv', compress=False)
#  |      Exports the list of tables to specified file format.
#  |
#  |      Parameters
#  |      ----------
#  |      path : str
#  |          Output filepath.
#  |      f : str
#  |          File format. Can be csv, excel, html, json, markdown or sqlite.
#  |      compress : bool
#  |          Whether or not to add files to a ZIP archive.
#  |
# ...

# %%
input_pdf.export("new", f='csv', compress=False)

# %%
input_pdf[1].df.loc[0:,0:]
# Out:
#       0                        1  \
# 0   20.             YAKUBU SAIDU
# 1
# 2   21.           BINTA HUSSAINI
# 3
# 4   22.   OBIGBESAN ADENIYI SETH
# 5   23.   OLUMODE SAMUEL ADEYEMI
# 6   24.     TAMUNOTONYE GODSWILL
# 7                          OGOLO
# 8   25.            IFEANYI OFILI
# 9   26.        EZENWAJIAKU NGOZI
# 10                       ANURIKA
# 11  27.  OLAJIDE DAVIDE ATOLAGBE
# 12  28.              BAWA NASIRU
# 13
# 14  29.        AHMAD SALEH USMAN
# 15  30.     KAYODETAJUDEEN USMAN
# 16  31.         AKOMOLAFE SUNDAY
# 17                       STEPHEN
# 18  32.         OLUSOLA VICTORIA
# 19                    OLUWASEYIN
# 20  33.      FASUYIN A. EMMANUEL
# 21  34.         MAGAJI OLAYIWOLA
# 22  35.            SIMEON OGBEDU
# 23  36.           FANAN GBAMWUAN
# 24  37.  ANAKE EMMANUEL UNIMNAKE
# 25  38.    AMBELE SADIYA MIEBAKA
# 26  39.       SHUAIBU ADAMU AUDU
#
#                                                     2                     3
# ...
